# %% [markdown]
# <h1>Week 2<h1>
# <ol>
#   <li>Tuple and list</li>
#   <li>For loop, while loop</li>
# </ol>

# %% [markdown]
# <h2>Tuple</h2>
# <p>รูปแบบตัวแปร ที่ เวลาสร้างสามารถสร้างได้มากกว่า 1 ตัว</p>

# %% [markdown]
# ![Screenshot 2566-08-15 at 20.23.01.png](data:image/png;base64,...)

# %%
A = (1,2,3)
print(A)

for i in A:
  print(i)
# Out:
# (1, 2, 3)
# 1
# 2
# 3

# %%
A[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b99cb8610388> in <cell line: 1>()
# ----> 1 A[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
A_Tuple = (1,2,3)
A_list = [1,2,3]
print(type(A_Tuple))
print(type(A_list))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
# len
print(len(A_Tuple))
print(len(A_list))
# Out:
# 3
# 3

# %%
print(A_list)
A_list.append(4)
print(A_list)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
A_list.append("Apple")
print(A_list)
# Out:
# [1, 2, 3, 4, 'Apple']

# %%
A_list.insert(0,'Banana')
print(A_list)
# Out:
# ['Banana', 1, 2, 3, 4, 'Apple']

# %%
A_list.insert(3, 'orange')
print(A_list)
# Out:
# ['Banana', 1, 2, 'orange', 3, 4, 'Apple']

# %%
A_list.clear()
print(A_list)
# Out:
# []

# %%
A_list = ['Banana', 1, 2, 'orange', 3, 4, 'Apple']
print(A_list)
A_list.remove('orange')
print(A_list)
# Out:
# ['Banana', 1, 2, 'orange', 3, 4, 'Apple']
# ['Banana', 1, 2, 3, 4, 'Apple']

# %%
A_list = ['Banana', 1, 2, 'orange', 3, 4, 'Apple']
print(A_list)
A_list.pop(0)
print(A_list)
# Out:
# ['Banana', 1, 2, 'orange', 3, 4, 'Apple']
# [1, 2, 'orange', 3, 4, 'Apple']

# %%
A_list = [1,2,2,3,4,2,5]
print(A_list)
A_list.remove(2)
print(A_list)
# Out:
# [1, 2, 2, 3, 4, 2, 5]
# [1, 2, 3, 4, 2, 5]

# %%
A_list = [10,1,2,4,20,3]
print(A_list)
A_list.sort()
print(A_list)
# Out:
# [10, 1, 2, 4, 20, 3]
# [1, 2, 3, 4, 10, 20]

# %%
print(A_list)
A_list.reverse()
print(A_list)
# Out:
# [1, 2, 3, 4, 10, 20]
# [20, 10, 4, 3, 2, 1]

# %%
text = "insert 0 5"
receive = text.split(" ")
print(receive)
print(receive[0])
# Out:
# ['insert', '0', '5']
# insert

# %%
text2 = "A,B,C,D"
receive2 = text2.split(",")
print(receive2)
# Out:
# ['A', 'B', 'C', 'D']

# %% [markdown]
# <h2>Command python with List</h2>
# <ol>
#   <li> append : เพิ่มข้อมูลเข้าไปใน list => ตำแหน่งสุดท้ายเสมอ <p>A.append(ค่าที่ต้องการ)</p> </li>
#   <li> insert : เพิ่มข้อมูลเข้าไปใน list + ตำแหน่งที่ต้องการ => <p>A.insert(ตำแหน่ง(int), ค่าที่ต้องการ)</p>
#   <li> clear : ล้างข้อมูลทั้งหมดใน list<p>A.clear()</p></li>
#   <li> remove : ลบข้อมูลใน list เฉพาะ ตัวที่มีค่าเท่ากันกับที่ส่งไป
#   <p>
#     A.remove(ค่าที่ต้่องการที่จะลบ)
#   </p>
#   </li>
#   <li> pop : ลบข้อมูลใน list เฉพาะ ตำแหน่งที่ต้องการ
#   <p>
#     A.pop(ตำแหน่งที่ต้องการจะลบ)
#   </p>
#   </li>
# </li>
#   <li> sort : เรียงข้อมูลจากน้อยไปหามาก
#   <p>
#     A.sort()
#   </p>
#   </li>
#    <li> reverse : กลับด้านข้อมูล
#   <p>
#     A.reverse()
#   </p>
#   </li>
#   <li> len : ดูจำนวนข้อมูลใน list
#   <p>
#     len(ชื่อของ list)
#   </p>
#   </li>
# </ol>

# %%
N = int(input())
result = []
for i in rang (N) :
     recetive = input().split()
     command = recetive[0]
     if(command == "insert") :
          result.insert(int(recetive[1]), int (recetive[2]))
     elif(command == "print") :
           print(result)
     elif(command == "remove") :
           resuit.remove(int(receive[1]))
     elif(command == "append") :
           resuit.append(9)
     elif(command == "append") :
           resuit.append(1)
     elif(command == "sort"):
           result.sort()
     elif(command == "print") :
           print(result)
     elif(command == "pop"):
           result.pop()
     elif(command == "reverse"):
           result.reverse()
     else(command == "print") :
           print(result)
